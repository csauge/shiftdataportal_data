# %%
# !pip install owid-catalog
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from owid.catalog import RemoteCatalog
# find the default OWID catalog and fetch the catalog index over HTTPS
catalog = RemoteCatalog(channels=('garden', 'meadow', 'open_numbers'))

# %%
# All namespaces = main sources
catalog.datasets
# Out:
#           namespace     version                                   dataset
# 0                un  2023-01-24                                    un_sdg
# 682      demography  2022-11-30                           life_expectancy
# 683         faostat  2023-02-22                      additional_variables
# 684         regions  2023-01-01                                   regions
# 685         faostat  2023-02-22                          faostat_metadata
# ...             ...         ...                                       ...
# 19996  open_numbers        None           who__violence_injury_prevention
# 30405  open_numbers        None             gapminder__dont_panic_poverty
# 38446  open_numbers        None                      gapminder__hist_u5mr
# 39077  open_numbers        None  ihme__global_burden_disease_ylds_by_risk
# 39088  open_numbers        None  ihme__global_burden_disease_ylls_by_risk
#
# [265 rows x 3 columns]

# %%
# GET LATEST VERSIONS of datasets
import pandas as pd
import numpy as np
import datetime

df=catalog.datasets

# Replace "None" versions with current date to include open_numbers namespace
current_date = datetime.datetime.now().strftime('%Y-%m-%d')
df['version'] = np.where(df['version'].str.contains('None|latest'), current_date, df['version'])

# Convert the 'version' column to a datetime format
df['version'] = pd.to_datetime(df['version'])

# Group the data by 'dataset', and get the row indices with the latest version
idx_latest_version = df.groupby(['namespace','dataset'])['version'].idxmax()

# Filter the DataFrame by the row indices of the latest versions
df = df.loc[idx_latest_version]
df.sort_values(df['id'], ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/_work/d4g/sdp/shiftdataportal_data/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/_work/d4g/sdp/shiftdataportal_data/.venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/_work/d4g/sdp/shiftdataportal_data/.venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# ...

# %%
# Emission 
df=df[df["dataset"].str.contains("gh|green|house|carbon|co2|emission")]
df
# Out:
#          namespace    version                                         dataset
# 706         andrew 2019-12-03                           co2_mitigation_curves
# 701           cait 2022-08-10                         ghg_emissions_by_sector
# 1100     emissions 2022-11-11                                        owid_co2
# 772   open_numbers 2023-05-04                                        who__gho
# 815            gcp 2023-04-28                            global_carbon_budget
# 922            gcp 2022-11-11       global_carbon_budget_fossil_co2_emissions
# 1021           gcp 2022-11-11           global_carbon_budget_global_emissions
# 1193           gcp 2022-11-11  global_carbon_budget_land_use_change_emissions
# 178            gcp 2022-11-11         global_carbon_budget_national_emissions
# 752   open_numbers 2023-05-04                      cait__historical_emissions
# 1614  open_numbers 2023-05-04                                      cdiac__co2
# ...

# %%
catalog.datasets[catalog.datasets["dataset"].str.contains("harvard__country_complexity_rankings")]
# Out:
#          namespace version                               dataset
# 3345  open_numbers    None  harvard__country_complexity_rankings

# %%
import pandas as pd
import numpy as np
import datetime

df=catalog.datasets[catalog.datasets["dataset"].str.contains("gh|green|house|carbon|co2|emission")]

# Replace missing versions with current date to include "open_numbers" namespace
current_date = datetime.datetime.now().strftime('%Y-%m-%d')
df['version'] = np.where(df['version']=='None', current_date, df['version'])

# Convert the 'version' column to a datetime format
df['version'] = pd.to_datetime(df['version'])

# Group the data by 'dataset', and get the row indices with the latest version
idx_latest_version = df.groupby(['namespace', 'dataset'])['version'].idxmax()

# Filter the DataFrame by the row indices of the latest versions
df = df.loc[idx_latest_version]
df
# Out:
#          namespace    version                                         dataset
# 706         andrew 2019-12-03                           co2_mitigation_curves
# 701           cait 2022-08-10                         ghg_emissions_by_sector
# 1100     emissions 2022-11-11                                        owid_co2
# 815            gcp 2023-04-28                            global_carbon_budget
# 922            gcp 2022-11-11       global_carbon_budget_fossil_co2_emissions
# 1021           gcp 2022-11-11           global_carbon_budget_global_emissions
# 1193           gcp 2022-11-11  global_carbon_budget_land_use_change_emissions
# 178            gcp 2022-11-11         global_carbon_budget_national_emissions
# 752   open_numbers 2023-05-04                      cait__historical_emissions
# 1614  open_numbers 2023-05-04                                      cdiac__co2
# 2068  open_numbers 2023-05-04                         gapminder__co2_emission
# ...

# %%
#  !!!! FROM SHIFT DATA PORTAL (UP TO 2016)
dataset = catalog.find_latest(None,namespace='shift')
print(dataset.metadata.dataset)
dataset.sort_values('year', ascending=False).head()
# Out:
# DatasetMeta(namespace='shift', short_name='fossil_fuel_production', title='Energy production from fossil fuels (Shift, 2022)', description='Data sources\nProduction (1900-2016)\nEtemad & Luciani for the period 1900-1980 Bouda Etemad and Jean Luciani, World Energy Production 1900 – 1985, ISBN 2-600-56007-6, Data digitalized and published with agreement of B. Etemad\nUS EIA Historical Statistics for 1980-2016. U.S. Energy Information Administration, accessed on 2019-06-05\n', sources=[Source(name='The Shift Data Portal', description=None, url='https://www.theshiftdataportal.org/', source_data_url=None, owid_data_url='https://walden.nyc3.digitaloceanspaces.com/shift/2022-07-18/fossil_fuel_production.csv', date_accessed='2022-07-18', publication_date='2019-06-05', publication_year=2019, published_by=None, publisher_source=None)], licenses=[License(name='Creative Commons BY-SA 3.0', url='https://www.theshiftdataportal.org/legal-notice')], is_public=True, additional_info=None, version='202
# ...

# %%
df = catalog.find(namespace='eia')
print(df.metadata)
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_18233/1417879419.py in ?()
# ----> 2 df = catalog.find(namespace='eia')
#       3 print(df.metadata)
#       4 df.head()
#
# ~/_work/d4g/sdp/shiftdataportal_data/.venv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'CatalogFrame' object has no attribute 'metadata'

# %%
# DEFAULT LATEST BP

df = catalog.find_latest(namespace='bp', dataset='energy')
print(df.metadata.dataset)
df
